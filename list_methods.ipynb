# %% [markdown]
# <a href="https://colab.research.google.com/github/moreddydishwanthreddy/python-programming/blob/main/list_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##PYTHON LIST METHODS

# %%
students = ["kasi", "raju", "hasj"]
students.append('janu')

# %%
students
# Out:
# ['kasi', 'raju', 'hasj', 'janu']

# %%
students.remove("raju")

# %%
students
# Out:
# ['kasi', 'hasj', 'janu']

# %%
students.insert(0, "tanmay")

# %%
students
# Out:
# ['tanmay', 'kasi', 'hasj', 'janu']

# %%
students.pop()
# Out:
# 'janu'

# %%
students.index("hasj")
# Out:
# 2

# %% [markdown]
# ## count method

# %%
fruits =["kiwi" ,"guava", "sewa", "kiwi"]
fruits.count("kiwi")
# Out:
# 2

# %%
fruits.copy()
fruits
# Out:
# ['kiwi', 'guava', 'sewa', 'kiwi']

# %%
fruits.clear()
fruits
# Out:
# []

# %%
tuple =(1,2,3,4,2,3,2)

# %%
tuple.count(2)
# Out:
# 3

# %%
tuple.index(2)
# Out:
# 1

# %%
set = {"p", "a", "p", "a"}

# %%
set.add("p")

# %%
set
# Out:
# {'a', 'p'}

# %%
set.remove('p')

# %%
set
# Out:
# {'a'}

# %%
set.clear()

# %%
set
# Out:
# set()

# %%
set.copy()
# Out:
# set()

# %% [markdown]
# #set methods list

# %%
a = {10,20,30}
b = {40,50,60}

# %%
a.union(b)
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
a = {"jashwanth"}
b = {"reddy"}

# %%
a.union(b)
# Out:
# {'jashwanth', 'reddy'}

# %%
a = {1,2,3}
b = {3,5,6}
a.intersection(b)
# Out:
# {3}
